# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
import matplotlib.pyplot as plt
import seaborn as sns

# %%
stats = pd.read_csv("stats/stats.csv", sep=";")
stats.head()
# Out:
#    red_fighter_name blue_fighter_name  event_date red_fighter_nickname  \
# 0      ILIA TOPURIA      MAX HOLLOWAY  26/10/2024           El Matador
# 1  ROBERT WHITTAKER   KHAMZAT CHIMAEV  26/10/2024           The Reaper
# 2  MAGOMED ANKALAEV  ALEKSANDAR RAKIC  26/10/2024                    -
# 3     LERONE MURPHY           DAN IGE  26/10/2024          The Miracle
# 4   SHARA MAGOMEDOV   ARMEN PETROSYAN  26/10/2024               Bullet
#
#   blue_fighter_nickname red_fighter_result blue_fighter_result  \
# 0               Blessed                  W                   L
# 1                  Borz                  L                   W
# 2                Rocket                  W                   L
# 3                   50K                  W                   L
# 4              Superman                  W                   L
#
#                  method  round  time  ... red_fighter_sig_str_body_pct  \
# 0                KO/TKO      3  1:34  ...                           14
# ...

# %%
fighters = pd.read_csv("fighter_stats/pro_mma_fighters.csv", sep=",")
fighters.head()
# Out:
#                                   url        fighter_name        nickname  \
# 0  /fighter/Kharun-Atlangeriev-167431  Kharun Atlangeriev        Predator
# 1         /fighter/Shojin-Miki-157565         Shojin Miki  Mini Margarito
# 2          /fighter/Ryan-Keenan-33827         Ryan Keenan        Who Dat?
# 3        /fighter/Dustin-Jacoby-73825       Dustin Jacoby      The Hanyak
# 4   /fighter/Richardson-Moreira-72825  Richardson Moreira    Rick Monstro
#
#    birth_date   age death_date              location        country height  \
# 0  05/10/1992  28.0        NaN                   NaN         Russia  5'10"
# 1         NaN   NaN        NaN      Honolulu, Hawaii  United States   5'9"
# 2  15/06/1985  36.0        NaN   Windermere, Florida  United States   6'0"
# 3  04/04/1988  33.0        NaN  Arenzville, Illinois  United States   6'4"
# 4  31/03/1984  37.0        NaN   Campinas, Sao Paulo         Brazil   6'2"
#
# ...

# %%
fighters2 = pd.read_csv("fighter_stats/fighter_stats.csv", sep=",")
fighters2.head()
# Out:
#                 name    nickname  wins  losses  draws  height_cm  \
# 0    Robert Drysdale         NaN     7       0      0     190.50
# 1  Daniel McWilliams  The Animal    15      37      0     185.42
# 2         Dan Molina         NaN    13       9      0     177.80
# 3          Paul Ruiz         NaN     7       4      0     167.64
# 4    Collin Huckbody      All In     8       2      0     190.50
#
#    weight_in_kg  reach_in_cm    stance date_of_birth  \
# 0         92.99          NaN  Orthodox    1981-10-05
# 1         83.91          NaN       NaN           NaN
# 2         97.98          NaN       NaN           NaN
# 3         61.23          NaN       NaN           NaN
# 4         83.91       193.04  Orthodox    1994-09-29
#
#    significant_strikes_landed_per_minute  significant_striking_accuracy  \
# 0                                   0.00                            0.0
# 1                                   3.36                           77.0
# ...

# %%
fighters_stats = pd.DataFrame()
fighters_stats["fighter"] = pd.concat([stats["red_fighter_name"], stats["blue_fighter_name"]])
fighters_stats["result"] = pd.concat([stats["red_fighter_result"], stats["blue_fighter_result"]])
fighters_stats["nickname"] = pd.concat([stats["red_fighter_nickname"], stats["blue_fighter_nickname"]])
fighters_stats["event_date"] = stats["event_date"].reset_index(drop=True)

# %%
# find match for fighters and fighters_stats
fighter_names = fighters["fighter_name"].unique()
fighter_stats_names = fighters_stats["fighter"].unique()

# %%
print(len(fighter_names))   
print(len(fighter_stats_names))
# Out:
# 5141
# 2523

# %%
type(fighter_names[0])
# Out:
# str

# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import string

nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/lucijaaleksic/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/lucijaaleksic/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
fighter_names = [str(name).lower() for name in fighter_names]
fighter_stats_names = [str(name).lower() for name in fighter_stats_names]

# %%
# match fighter names to fighter stats names
matches = []
for name in fighter_names:
    for stats_name in fighter_stats_names:
        if name in stats_name:
            matches.append((name, stats_name))

print(len(matches))
# Out:
# 2069
